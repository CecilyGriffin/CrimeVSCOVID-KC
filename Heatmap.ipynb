# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
crime_df = pd.read_csv('Resources/KCPD_Crime_Data.csv')
crime_df.dropna(inplace = True) 
crime_df.head()
# Out:
#       Report_No Reported_Date            Reported_Time   From_Date  \
# 384  KC20011765    02/15/2020  2020-02-15T20:03:38.000  02/10/2020
# 385  KC20012815    02/20/2020  2020-02-20T06:55:03.000  02/19/2020
# 398  KC20007266    01/29/2020  2020-01-29T16:25:56.000  01/29/2020
# 410  KC20008528    02/03/2020  2020-02-03T12:10:14.000  12/17/2019
# 419  KC20008819    02/04/2020  2020-02-04T11:21:03.000  02/02/2020
#
#                    From_Time     To_Date                  To_Time  \
# 384  2020-02-10T12:00:00.000  02/15/2020  2020-02-15T15:00:00.000
# 385  2020-02-19T00:01:00.000  02/20/2020  2020-02-20T06:50:00.000
# 398  2020-01-29T05:30:00.000  01/29/2020  2020-01-29T16:50:00.000
# 410  2019-12-17T03:52:00.000  02/03/2020  2020-02-03T12:10:00.000
# 419  2020-02-02T11:34:00.000  02/04/2020  2020-02-04T10:29:00.000
#
#                                        Offense IBRS  \
# 384                                Stolen Auto  23F
# 385       Stealing from Auto (Theft from Auto)  23F
# 398                     Burglary (Residential)  220
# 410                             Identity Theft  26F
# 419  Violation of Ex-Parte Order of Protection  90Z
#
#                         Description  ... Zip Code Rep_Dist Area  DVFlag  \
# 384        Theft From Motor Vehicle  ...  64106.0   PJ0696  CPD       N
# 385        Theft From Motor Vehicle  ...  64111.0   PJ3372  CPD       N
# 398  Burglary/Breaking and Entering  ...  64129.0   PJ4134  MPD       N
# 410                  Identity Theft  ...  64151.0   PP0691  NPD       N
# 419              All Other Offenses  ...  64114.0   PJ6193  MPD       Y
#
#     Involvement Race Sex   Age Firearm Used Flag  \
# 384         VIC    W   M  60.0             False
# 385         VIC    W   F  23.0             False
# 398         SUS    B   M  22.0             False
# 410         VIC    W   M  59.0             False
# 419         VIC    B   F  30.0             False
#
#                                               Location
# 384  W 8TH ST and MULBERRY ST\nKANSAS CITY 64106\n(...
# 385  4100  OAK ST\nKANSAS CITY 64111\n(39.051476, -...
# 398  7600  SNI-A-BAR RD\nKANSAS CITY 64129\n(39.035...
# 410  5700  N HUTSON RD\nKANSAS CITY 64151\n(39.1987...
# 419  8700  WORNALL RD\nKANSAS CITY 64114\n(38.97066...
#
# [5 rows x 23 columns]

# %%
location = crime_df["Location"]= crime_df["Location"].str.split("(", n = 1, expand = True) 
  
location
# Out:
#                                                    0                       1
# 384    W 8TH ST and MULBERRY ST\nKANSAS CITY 64106\n  39.105094, -94.599678)
# 385                4100  OAK ST\nKANSAS CITY 64111\n  39.051476, -94.581738)
# 398          7600  SNI-A-BAR RD\nKANSAS CITY 64129\n  39.035286, -94.495582)
# 410           5700  N HUTSON RD\nKANSAS CITY 64151\n  39.198787, -94.620837)
# 419            8700  WORNALL RD\nKANSAS CITY 64114\n   38.970664, -94.59528)
# ...                                              ...                     ...
# 47953           2400  E 11TH ST\nKANSAS CITY 64127\n  39.100736, -94.553634)
# 47978           8500  E 99TH ST\nKANSAS CITY 64134\n  38.944361, -94.491134)
# 47982        12200  N POMONA LN\nKANSAS CITY 64153\n  39.315115, -94.671276)
# 47984        5300  BROOKLYN AVE\nKANSAS CITY 64130\n  39.030194, -94.559609)
# 48013           3400  LOCUST ST\nKANSAS CITY 64109\n  39.065318, -94.579765)
#
# [2765 rows x 2 columns]

# %%
location = location[1]= location[1].str.split(",", n = 1, expand = True) 
  
location
# Out:
#                0          1
# 384    39.105094  39.105094
# 385    39.051476  39.051476
# 398    39.035286  39.035286
# 410    39.198787  39.198787
# 419    38.970664  38.970664
# ...          ...        ...
# 47953  39.100736  39.100736
# 47978  38.944361  38.944361
# 47982  39.315115  39.315115
# 47984  39.030194  39.030194
# 48013  39.065318  39.065318
#
# [2765 rows x 2 columns]

# %%
renamed= location.rename(columns={0: "Lat", 1:"Lng"})
renamed
# Out:
#              Lat        Lng
# 384    39.105094  39.105094
# 385    39.051476  39.051476
# 398    39.035286  39.035286
# 410    39.198787  39.198787
# 419    38.970664  38.970664
# ...          ...        ...
# 47953  39.100736  39.100736
# 47978  38.944361  38.944361
# 47982  39.315115  39.315115
# 47984  39.030194  39.030194
# 48013  39.065318  39.065318
#
# [2765 rows x 2 columns]

# %%
coordinates= renamed[["Lat","Lng"]]
coordinates
# Out:
#              Lat        Lng
# 384    39.105094  39.105094
# 385    39.051476  39.051476
# 398    39.035286  39.035286
# 410    39.198787  39.198787
# 419    38.970664  38.970664
# ...          ...        ...
# 47953  39.100736  39.100736
# 47978  38.944361  38.944361
# 47982  39.315115  39.315115
# 47984  39.030194  39.030194
# 48013  39.065318  39.065318
#
# [2765 rows x 2 columns]

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(coordinates,
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-c1895ffef8f7> in <module>
#       5 heat_layer = gmaps.heatmap_layer(coordinates,
#       6                                  dissipating=False, max_intensity=10,
# ----> 7                                  point_radius=1)
#       8
#       9
#
# ~\Anaconda3\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     269         return WeightedHeatmap(**widget_args)
#     270     else:
# --> 271         return Heatmap(**widget_args)
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~\Anaconda3\lib\site-packages\gmaps\heatmap.py in _calc_bounds(self, change)
#     129     def _calc_bounds(self, change):
#     130         data = change['new']
# --> 131         self.set_bounds(data)
#     132
#     133
#
# ~\Anaconda3\lib\site-packages\gmaps\heatmap.py in set_bounds(self, data)
#      69         latitudes = [row[0] for row in data]
#      70         longitudes = [row[1] for row in data]
# ---> 71         min_latitude, max_latitude = self._latitude_bounds(latitudes)
#      72         min_longitude, max_longitude = self._longitude_bounds(longitudes)
#      73         self.data_bounds = [
#
# ~\Anaconda3\lib\site-packages\gmaps\heatmap.py in _latitude_bounds(self, latitudes)
#      77
#      78     def _latitude_bounds(self, latitudes):
# ---> 79         return bounds.latitude_bounds(latitudes)
#      80
#      81     def _longitude_bounds(self, longitudes):
#
# ~\Anaconda3\lib\site-packages\gmaps\bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
