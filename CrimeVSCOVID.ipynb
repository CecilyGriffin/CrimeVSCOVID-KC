# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
crime_file = "Resources/KCPD_Crime_Data.csv"
crime_df = pd.read_csv(crime_file)
crime_df.head()
# Out:
#     Report_No Reported_Date            Reported_Time   From_Date  \
# 0  KC20000013    01/01/2020  2020-01-01T00:16:58.000  01/01/2020
# 1  KC20000076    01/01/2020  2020-01-01T08:16:32.000  01/01/2020
# 2  KC20000125    01/01/2020  2020-01-01T12:41:34.000  01/01/2020
# 3  KC20000164    01/01/2020  2020-01-01T15:40:50.000  01/01/2020
# 4  KC20000304    01/02/2020  2020-01-02T09:45:51.000  01/01/2020
#
#                  From_Time To_Date To_Time  \
# 0  2020-01-01T01:15:00.000     NaN     NaN
# 1  2020-01-01T09:00:00.000     NaN     NaN
# 2  2020-01-01T12:41:00.000     NaN     NaN
# 3  2020-01-01T15:39:00.000     NaN     NaN
# 4  2020-01-01T14:00:00.000     NaN     NaN
#
#                                       Offense IBRS               Description  \
# 0                        Assault (Aggravated)  13A        Aggravated Assault
# 1               City/Municipal Warrant Arrest  NaN                       NaN
# ...

# %%
covid_file = "COVID-Data.csv"
covid_df = pd.read_csv(crime_file)
covid_df.head()
# Out:
#     Report_No Reported_Date            Reported_Time   From_Date  \
# 0  KC20000013    01/01/2020  2020-01-01T00:16:58.000  01/01/2020
# 1  KC20000076    01/01/2020  2020-01-01T08:16:32.000  01/01/2020
# 2  KC20000125    01/01/2020  2020-01-01T12:41:34.000  01/01/2020
# 3  KC20000164    01/01/2020  2020-01-01T15:40:50.000  01/01/2020
# 4  KC20000304    01/02/2020  2020-01-02T09:45:51.000  01/01/2020
#
#                  From_Time To_Date To_Time  \
# 0  2020-01-01T01:15:00.000     NaN     NaN
# 1  2020-01-01T09:00:00.000     NaN     NaN
# 2  2020-01-01T12:41:00.000     NaN     NaN
# 3  2020-01-01T15:39:00.000     NaN     NaN
# 4  2020-01-01T14:00:00.000     NaN     NaN
#
#                                       Offense IBRS               Description  \
# 0                        Assault (Aggravated)  13A        Aggravated Assault
# 1               City/Municipal Warrant Arrest  NaN                       NaN
# ...

# %%
new_crime_df = crime_df[['id', 'first_name', 'last_name']].copy()
new_crime_df.head()
