# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
COVID_path = "API-CSV/NewCOVID.csv"
Crime_path = "API-CSV/NewCrime.csv"

COVID = pd.read_csv(COVID_path)
Crime = pd.read_csv(Crime_path)

# %%
# Combine the data into a single dataset
combined = pd.merge(COVID, Crime, how='outer', on='zip_code')
combined
# Out:
#        Unnamed: 0_x  zip_code  cases  crude_rate_per_100_000  Unnamed: 0_y  \
# 0               3.0   64106.0  186.0                 1994.42             3
# 1               3.0   64106.0  186.0                 1994.42             5
# 2               3.0   64106.0  186.0                 1994.42            37
# 3               3.0   64106.0  186.0                 1994.42            49
# 4               3.0   64106.0  186.0                 1994.42            86
# ...             ...       ...    ...                     ...           ...
# 60051           NaN   64195.0    NaN                     NaN         51072
# 60052           NaN   66101.0    NaN                     NaN         49318
# 60053           NaN   66109.0    NaN                     NaN         53425
# 60054           NaN   64321.0    NaN                     NaN         59627
# 60055           NaN   64192.0    NaN                     NaN         59834
#
#        firearm_used_flag   report_no  \
# 0                  False  KC20000565
# 1                  False  KC20000663
# 2                  False  KC20004710
# 3                  False  KC20006258
# 4                  False  KC20010753
# ...                  ...         ...
# 60051              False  KC20040462
# 60052              False  KC20046700
# 60053              False  KC20053356
# 60054              False  KC20053150
# 60055              False  KC20049052
#
#                                            offense  \
# 0                             State Warrant Arrest
# 1                     Outside State Warrant Arrest
# 2                         Assault (Non-Aggravated)
# 3                        Trespass of Real Property
# 4                                       Buy Report
# ...                                            ...
# 60051  Failure to Return Leased or Rented Property
# 60052  Stealing from Auto (Auto Part or Accessory)
# 60053                     Alcohol Influence Report
# 60054         Stealing from Auto (Theft from Auto)
# 60055                             Stealing – Other
#
#                              description  sex   age race
# 0                                    NaN    F  36.0    B
# 1                                    NaN    F  50.0    W
# 2                         Simple Assault    M  34.0    W
# 3              Trespass of Real Property    M  20.0    W
# 4                                    NaN    M  30.0    B
# ...                                  ...  ...   ...  ...
# 60051                Motor Vehicle Theft  NaN   NaN  NaN
# 60052  Vandalism/Destruction of Property    M  28.0    W
# 60053        Driving Under the Influence    M  35.0    B
# 60054           Theft From Motor Vehicle    F  22.0    B
# 60055                  All Other Larceny  NaN   NaN  NaN
#
# [60056 rows x 12 columns]

# %%
combined=combined.rename(columns={"zip_code":"Zip Code","cases":"COVID Cases","crude_rate_per_100_000":"Crude Rate Per 100,000","sex":"Sex"\
                                  ,"firearm_used_flag":"Firearm Used","report_no":"Report Number", "description":"Crime Description","age":"Age", "offense":"Offense", "race":"Race"})
combined.head()
# Out:
#    Unnamed: 0_x  Zip Code  COVID Cases  Crude Rate Per 100,000  Unnamed: 0_y  \
# 0           3.0   64106.0        186.0                 1994.42             3
# 1           3.0   64106.0        186.0                 1994.42             5
# 2           3.0   64106.0        186.0                 1994.42            37
# 3           3.0   64106.0        186.0                 1994.42            49
# 4           3.0   64106.0        186.0                 1994.42            86
#
#    Firearm Used Report Number                       Offense  \
# 0         False    KC20000565          State Warrant Arrest
# 1         False    KC20000663  Outside State Warrant Arrest
# 2         False    KC20004710      Assault (Non-Aggravated)
# 3         False    KC20006258     Trespass of Real Property
# 4         False    KC20010753                    Buy Report
#
#            Crime Description Sex   Age Race
# 0                        NaN   F  36.0    B
# 1                        NaN   F  50.0    W
# 2             Simple Assault   M  34.0    W
# 3  Trespass of Real Property   M  20.0    W
# 4                        NaN   M  30.0    B

# %%
#combined.replace(["NaN", 'NaT'], np.nan, inplace = True)
#combined_new = combined.dropna()
#combined_new

# %%
combined_new=pd.DataFrame(combined)

# %%
combined_new.columns
# Out:
# Index(['Unnamed: 0_x', 'Zip Code', 'COVID Cases', 'Crude Rate Per 100,000',
#        'Unnamed: 0_y', 'Firearm Used', 'Report Number', 'Offense',
#        'Crime Description', 'Sex', 'Age', 'Race'],
#       dtype='object')

# %%
combined_df=combined_new.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'])
combined_df
# Out:
#        Zip Code  COVID Cases  Crude Rate Per 100,000  Firearm Used  \
# 0       64106.0        186.0                 1994.42         False
# 1       64106.0        186.0                 1994.42         False
# 2       64106.0        186.0                 1994.42         False
# 3       64106.0        186.0                 1994.42         False
# 4       64106.0        186.0                 1994.42         False
# ...         ...          ...                     ...           ...
# 60051   64195.0          NaN                     NaN         False
# 60052   66101.0          NaN                     NaN         False
# 60053   66109.0          NaN                     NaN         False
# 60054   64321.0          NaN                     NaN         False
# 60055   64192.0          NaN                     NaN         False
#
#       Report Number                                      Offense  \
# 0        KC20000565                         State Warrant Arrest
# 1        KC20000663                 Outside State Warrant Arrest
# 2        KC20004710                     Assault (Non-Aggravated)
# 3        KC20006258                    Trespass of Real Property
# 4        KC20010753                                   Buy Report
# ...             ...                                          ...
# 60051    KC20040462  Failure to Return Leased or Rented Property
# 60052    KC20046700  Stealing from Auto (Auto Part or Accessory)
# 60053    KC20053356                     Alcohol Influence Report
# 60054    KC20053150         Stealing from Auto (Theft from Auto)
# 60055    KC20049052                             Stealing – Other
#
#                        Crime Description  Sex   Age Race
# 0                                    NaN    F  36.0    B
# 1                                    NaN    F  50.0    W
# 2                         Simple Assault    M  34.0    W
# 3              Trespass of Real Property    M  20.0    W
# 4                                    NaN    M  30.0    B
# ...                                  ...  ...   ...  ...
# 60051                Motor Vehicle Theft  NaN   NaN  NaN
# 60052  Vandalism/Destruction of Property    M  28.0    W
# 60053        Driving Under the Influence    M  35.0    B
# 60054           Theft From Motor Vehicle    F  22.0    B
# 60055                  All Other Larceny  NaN   NaN  NaN
#
# [60056 rows x 10 columns]

# %%
combined_df.replace(["NaN", 'NaT'], np.nan, inplace = True)
combined_new = combined_df.dropna()
combined_new
# Out:
#        Zip Code  COVID Cases  Crude Rate Per 100,000  Firearm Used  \
# 2       64106.0        186.0                 1994.42         False
# 3       64106.0        186.0                 1994.42         False
# 5       64106.0        186.0                 1994.42         False
# 8       64106.0        186.0                 1994.42         False
# 15      64106.0        186.0                 1994.42         False
# ...         ...          ...                     ...           ...
# 47575   64158.0         81.0                 1606.82         False
# 47576   64158.0         81.0                 1606.82         False
# 47577   64158.0         81.0                 1606.82         False
# 47578   64158.0         81.0                 1606.82         False
# 47580   64158.0         81.0                 1606.82         False
#
#       Report Number                                        Offense  \
# 2        KC20004710                       Assault (Non-Aggravated)
# 3        KC20006258                      Trespass of Real Property
# 5        KC20010978                       Assault (Non-Aggravated)
# 8        KC20026138                          Stealing – Pickpocket
# 15       KC20052865                           Assault (Aggravated)
# ...             ...                                            ...
# 47575    KC20051996  Harassment / Intimidation - Domestic Violence
# 47576    KC20050902                            Stealing – Shoplift
# 47577    KC20049356                                Property Damage
# 47578    KC20049323           Stealing from Auto (Theft from Auto)
# 47580    KC20048376             Endangering the Welfare of a Child
#
#                        Crime Description Sex   Age Race
# 2                         Simple Assault   M  34.0    W
# 3              Trespass of Real Property   M  20.0    W
# 5                         Simple Assault   M  23.0    W
# 8                         Pocket-Picking   F  52.0    B
# 15                    Aggravated Assault   M  50.0    W
# ...                                  ...  ..   ...  ...
# 47575                       Intimidation   M  40.0    W
# 47576                  All Other Larceny   M  20.0    B
# 47577  Vandalism/Destruction of Property   F  40.0    W
# 47578                  All Other Larceny   M  25.0    W
# 47580  Vandalism/Destruction of Property   M  30.0    B
#
# [31425 rows x 10 columns]

# %%
race= combined_new["Sex"].value_counts()
race_pybar= race.plot(kind="pie",autopct = "%1.1f%%")
plt.savefig("crimesex.png")
plt.title("The Propotion of Criminal based on gender")
plt.legend()
plt.show()
plt.tight_layout()

# %%
combined_new_reduced_df = combined_new[['Zip Code','Crude Rate Per 100,000','Crime Description']]
combined_new_reduced_df
# Out:
#        Zip Code  Crude Rate Per 100,000                  Crime Description
# 2       64106.0                 1994.42                     Simple Assault
# 3       64106.0                 1994.42          Trespass of Real Property
# 5       64106.0                 1994.42                     Simple Assault
# 8       64106.0                 1994.42                     Pocket-Picking
# 15      64106.0                 1994.42                 Aggravated Assault
# ...         ...                     ...                                ...
# 47575   64158.0                 1606.82                       Intimidation
# 47576   64158.0                 1606.82                  All Other Larceny
# 47577   64158.0                 1606.82  Vandalism/Destruction of Property
# 47578   64158.0                 1606.82                  All Other Larceny
# 47580   64158.0                 1606.82  Vandalism/Destruction of Property
#
# [31425 rows x 3 columns]

# %%
#combined_new_reduced_df.dtypes
# Out:
# Zip Code                  float64
# Crude Rate Per 100,000    float64
# Crime Description          object
# dtype: object

# %%
offense_df= combined_new_reduced_df[['Zip Code','Crude Rate Per 100,000','Crime Description']]
offense_df
# Out:
#        Zip Code  Crude Rate Per 100,000                  Crime Description
# 2       64106.0                 1994.42                     Simple Assault
# 3       64106.0                 1994.42          Trespass of Real Property
# 5       64106.0                 1994.42                     Simple Assault
# 8       64106.0                 1994.42                     Pocket-Picking
# 15      64106.0                 1994.42                 Aggravated Assault
# ...         ...                     ...                                ...
# 47575   64158.0                 1606.82                       Intimidation
# 47576   64158.0                 1606.82                  All Other Larceny
# 47577   64158.0                 1606.82  Vandalism/Destruction of Property
# 47578   64158.0                 1606.82                  All Other Larceny
# 47580   64158.0                 1606.82  Vandalism/Destruction of Property
#
# [31425 rows x 3 columns]

# %%
average_rate = combined_new_reduced_df.mean()
offense = offense_df.keys(4)
average_rate.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-be32ad4a5ec0> in <module>
#       1 average_rate = combined_new_reduced_df.mean()
# ----> 2 offense = offense_df.keys(4)
#
# TypeError: keys() takes 1 positional argument but 2 were given

# %%
firearm= combined_new["Firearm Used"].value_counts()

firearm_pybar= firearm.plot(kind="pie",autopct = "%1.1f%%")
plt.savefig("crimegenerder.png")
plt.show()
plt.tight_layout()

# %%
combined_new["Zip Code"]=pd.to_numeric(combined_new["Zip Code"])
combined_new

# %%
#zip_count= combined_new["Zip Code"].value_counts()
#zip_count

# %%
offense_count= combined_new["Crime Description"].value_counts()
offense_count

# %%
covid=pd.DataFrame(COVID)
covid.head()

# %%
x_values = covid['zip_code']
y_values = covid['cases']
plt.scatter(x_values,y_values, alpha=.8, edgecolors="black")
plt.xlabel('Zip Code')
plt.ylabel('COVID Cases')
plt.title('Zip Code vs. COVID Cases')
plt.grid()
plt.savefig("zipvscovid.png")
plt.show()

# %%
crime=pd.DataFrame(Crime)
crime.replace(["NaN", 'NaT'], np.nan, inplace = True)
crime_new = crime.dropna()
crime_new

# %%
race_count = crime_new["race"].value_counts()
race_count
